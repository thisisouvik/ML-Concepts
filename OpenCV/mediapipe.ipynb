# %%
pip install mediapipe opencv-python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement mediapipe (from versions: none)
# ERROR: No matching distribution found for mediapipe

# %%
import mediapipe as mp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import mediapipe as mp
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ref, frame = cap.read()
    cv2.imshow('web cam', frame)

    if cv2.waitKey(10) & 0xff == ('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cap = cv2.VideoCapture(0)
#       2 while cap.isOpened():
#       3     ref, frame = cap.read()
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# Drawing - POinting your faces or capture
# Holistic - Tracking your movements thourgh points

# %%
mp_drwaing= mp.solutions.drawing_utilities
mp_holistic= mp.solutions.Holistics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mp_drwaing= mp.solutions.drawing_utilities
#       2 mp_holistic= mp.solutions.Holistics
#
# NameError: name 'mp' is not defined

# %%
cam2= cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence= 0.5, min_tracking_confidence = 0.5) as Holistic:
    
    while cam2.isOpened():
        ref, frame = cam2.read()
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(img)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

        mp_drwaing.draw_landmarks(img, results.face_landmarks, np_holistic.FACEMESH_TESELATION, 
                                  np.drawing.DrawingSpec(colour = (0,255,0), thickness = 2, circle_radius = 2)
                                  np.drawing.DrawingSpec(colour = (0,255,0), thickness = 2, circle_radius = 2)
                                  )
        mp_drwaing.draw_landmarks(img, results.right_hand_landmarks, np_holistic.HAND_CONNECTIONS)
        mp_drwaing.draw_landmarks(img, results.left_hand_landmarks, np_holistic.HAND_CONNECTIONS)
        mp_drwaing.draw_landmarks(img, results.pose_landmarks, mp_holistics.POSE_COLLECTIONS)

        cv2.imshow("Holistic", cam2)\
        
        if cv2.waitKey(10) & 0xff == ('q'):
            break

cam2.release()
cv2.destroyAllWindows()
# Out:
#   Cell In[6], line 12
#     np.drawing.DrawingSpec(colour = (0,255,0), thickness = 2, circle_radius = 2)
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
mp.drawing.DrawingSpec(colour = (0,255,0), thickness = 2, circle_radius = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mp.drawing.DrawingSpec(colour = (0,255,0), thickness = 2, circle_radius = 2)
#
# NameError: name 'mp' is not defined

# %%
# Check if mediapipe is installed
import importlib.util
print(importlib.util.find_spec("mediapipe"))
# Out:
# None
