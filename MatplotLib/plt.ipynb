# %% [markdown]
# # Matplot Library in Python

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
data={
    "Salary": [25000 , 30000, 28000, 48000, 52000, 27000 ]
}

# %%
df=pd.DataFrame(data)

# %%
df.head()
df.shape
# Out:
# (6, 1)

# %%
plt.plot(df["Salary"])
plt.grid(True)
plt.show()
